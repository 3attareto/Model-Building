# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_nodes_from(['a', 'b', 'c', 'd'])
G.add_edges_from([('a','b'), ('b','c'), ('c','d'), ('a','c')])
nx.draw(G, with_labels = True,node_size=700)

# %%
list(G.neighbors('b'))
# Out:
# ['a', 'c']

# %%
for neighbor in G.neighbors('b'):
    print(neighbor)
# Out:
# a
# c

# %%
G.has_node('a')
# Out:
# True

# %%
nx.is_tree(G)
# Out:
# False

# %%
nx.is_connected(G)
# Out:
# True

# %%
G.degree('a')
# Out:
# 2

# %%
D = nx.DiGraph()
D.add_edges_from([('1','2'), ('2','3'), ('1','4'), ('3','4')])
nx.draw(D, with_labels = True)

# %%
X=nx.Graph()
X.add_edges_from([(1,2),(2,3),(1,3),(3,4)])
nx.draw(X,with_labels=True,node_size=500)

# %%
dict(X.degree())
# Out:
# {1: 2, 2: 2, 3: 3, 4: 1}

# %%
nx.to_numpy_matrix(X)
# Out:
# matrix([[0., 1., 1., 0.],
#         [1., 0., 1., 0.],
#         [1., 1., 0., 1.],
#         [0., 0., 1., 0.]])

# %%
graph=nx.read_edgelist('do-graph.txt',nodetype=str,create_using=nx.DiGraph())
nx.draw(graph,with_labels=True,node_size=500)
